# %% [markdown]
# # Python Data Types Practice Exercises

# %% [markdown]
# # Integer (int) Exercises

# %% [markdown]
# ## Exercise 1: Restaurant Bill Calculator
# You're building a point-of-sale system for a restaurant. Calculate the total bill for a table that ordered:
#
# 3 burgers at $12 each
# 2 sodas at $3 each
# 1 dessert at $8
#
# Write code to calculate the subtotal, add 8% tax, and display the final amount (convert to integer cents for payment processing).

# %%
burger = 12
soda = 3
dessert = 8
tax = 0.08

b = int(input(("enter number of burgers")))
s = int(input(("enter number of sodas")))
d = int(input(("enter number of desserts")))

amount = (b*burger) + (s*soda) + (d*dessert)
after_tax = amount * tax
total = amount + after_tax
total_cents = int(total * 100)

print(f"Subtotal: ${amount}")
print(f"Tax (8%): ${after_tax:.2f}")
print(f"Total: ${total:.2f}")
print(f"Total in cents: {total_cents}")
# Out:
# Subtotal: $124
# Tax (8%): $9.92
# Total: $133.92
# Total in cents: 13391

# %%
# Exercise 1: Restaurant Bill Calculator
print("\nExercise 1: Restaurant Bill Calculator")
burgers = 3 * 12
sodas = 2 * 3
dessert = 1 * 8
subtotal = burgers + sodas + dessert
tax = subtotal * 0.08
total = subtotal + tax
total_cents = int(total * 100)

print(f"Subtotal: ${subtotal}")
print(f"Tax (8%): ${tax:.3f}")
print(f"Total: ${total:.3f}")
print(f"Total in cents: {total_cents}")
# Out:
# Exercise 1: Restaurant Bill Calculator
# Subtotal: $50
# Tax (8%): $4.000
# Total: $54.000
# Total in cents: 5400

# %% [markdown]
# ## Exercise 2: Warehouse Inventory
# A warehouse receives shipments throughout the day. Starting inventory: 450 units. Track these transactions:
#
# Morning: +120 units delivered
# Afternoon: -85 units sold
# Evening: +200 units delivered, -95 units sold
#
# Calculate the final inventory count and determine if you need to reorder (reorder if below 500 units).

# %%
import datetime

def warehouse_inventory():
    """
    Simulates a warehouse inventory system, tracking sales, deliveries, 
    and reordering based on inventory levels.
    """

    inventory = 450
    daily_transactions = []  # List to store daily transactions
    
    while True:
        print("\n--- Warehouse Inventory ---")
        print(f"Current Inventory: {inventory}")
        print("1. Record Transaction")
        print("2. Calculate Final Inventory")
        print("3. Exit")

        choice = input("Enter your choice (1/2/3): ")

        if choice == '1':
            try:
                date_str = input("Enter date (YYYY-MM-DD): ")
                date = datetime.datetime.strptime(date_str, '%Y-%m-%d').date()

                transaction_type = input("Enter transaction type (Sold/Delivered): ").lower()
                quantity = int(input("Enter quantity: "))

                if transaction_type == 'sold':
                    inventory -= quantity
                    print(f"Sold {quantity} units. New inventory: {inventory}")
                elif transaction_type == 'delivered':
                    inventory += quantity
                    print(f"Delivered {quantity} units. New inventory: {inventory}")
                else:
                    print("Invalid transaction type.")

                daily_transactions.append({'date': date, 'transaction_type': transaction_type, 'quantity': quantity})
            
            except ValueError:
                print("Invalid input. Please enter a valid integer for quantity and date in YYYY-MM-DD format.")
            
        elif choice == '2':
            print("\n--- Daily Transactions ---")
            for transaction in daily_transactions:
                print(f"Date: {transaction['date']}, Type: {transaction['transaction_type']}, Quantity: {transaction['quantity']}")

            if inventory >= 500:
                print("Inventory is above 500 units. No reorder needed.")
            else:
                print("Inventory is below 500 units. Reorder needed.")
                
        elif choice == '3':
            break
        else:
            print("Invalid choice. Please enter 1, 2, or 3.")
    
    #Update starting inventory for the next day
    print("\n--- Final Inventory Report ---")
    print(f"Final Inventory: {inventory}")

    
#Run the simulation
warehouse_inventory()
# Out:
# --- Warehouse Inventory ---
# Current Inventory: 450
# 1. Record Transaction
# 2. Calculate Final Inventory
# 3. Exit
# Sold 400 units. New inventory: 50
#
# --- Warehouse Inventory ---
# Current Inventory: 50
# 1. Record Transaction
# 2. Calculate Final Inventory
# 3. Exit
#
# --- Daily Transactions ---
# Date: 2025-01-11, Type: sold, Quantity: 400
# Inventory is below 500 units. Reorder needed.
#
# --- Warehouse Inventory ---
# Current Inventory: 50
# 1. Record Transaction
# 2. Calculate Final Inventory
# 3. Exit
#
# --- Final Inventory Report ---
# Final Inventory: 50

# %%
# Exercise 2: Warehouse Inventory
print("\nExercise 2: Warehouse Inventory")
starting_inventory = 450
morning_delivery = 120
afternoon_sold = 85
evening_delivery = 200
evening_sold = 95

final_inventory = starting_inventory + morning_delivery - afternoon_sold + evening_delivery - evening_sold
need_reorder = final_inventory < 500

print(f"Starting inventory: {starting_inventory}")
print(f"Final inventory: {final_inventory}")
print(f"Need to reorder: {need_reorder}")
# Out:
# Exercise 2: Warehouse Inventory
# Starting inventory: 450
# Final inventory: 590
# Need to reorder: False

# %%
starting_inventory = 450
sold = []
try:
    sold_input = input("Enter units sold (e.g., 10 20 5): ")
    sold = [int(x) for x in sold_input.split()]  # Convert input to integers
    print(sold, type(sold))
except ValueError:
    print("Invalid input. Please enter numbers separated by spaces.")
    sold = [] # Reset sold list if there is a ValueError

# Now you can perform an inventory update:
starting_inventory -= sum(sold) # subtract sum of sold
print("Remaining inventory:", starting_inventory)
# Out:
# [] <class 'list'>
# Remaining inventory: 450

# %%
def update_inventory(starting_inventory, transactions):
    """
    Updates inventory based on sales transactions.

    Args:
        starting_inventory (int): The initial inventory level.
        transactions (list): A list of integers representing units sold.

    Returns:
        tuple: A tuple containing the final inventory level and a boolean
               indicating whether reordering is needed.
    """

    final_inventory = starting_inventory - sum(transactions)

    reorder_needed = final_inventory < 500

    return final_inventory, reorder_needed


def main():
    """
    Main function to handle user input and inventory updates.
    """

    starting_inventory = 450
    transactions = []
    transactions_data = {}  # Dictionary to store transaction details

    # Get sales transactions for morning, afternoon, and evening
    morning_sales_input = input("Enter units sold (morning) (e.g., 10 20 5): ")
    try:
        morning_sales = [int(x) for x in morning_sales_input.split()]
        transactions.extend(morning_sales)
        transactions_data["morning"] = morning_sales
    except ValueError:
        print("Invalid input. Please enter numbers separated by spaces for morning sales.")
        morning_sales = []

    afternoon_sales_input = input("Enter units sold (afternoon) (e.g., 10 20 5): ")
    try:
        afternoon_sales = [int(x) for x in afternoon_sales_input.split()]
        transactions.extend(afternoon_sales)
        transactions_data["afternoon"] = afternoon_sales
    except ValueError:
        print("Invalid input. Please enter numbers separated by spaces for afternoon sales.")
        afternoon_sales = []

    evening_sales_input = input("Enter units sold (evening) (e.g., 10 20 5): ")
    try:
        evening_sales = [int(x) for x in evening_sales_input.split()]
        transactions.extend(evening_sales)
        transactions_data["evening"] = evening_sales
    except ValueError:
        print("Invalid input. Please enter numbers separated by spaces for evening sales.")
        evening_sales = []

    final_inventory, reorder_needed = update_inventory(starting_inventory, transactions)

    print("Final Inventory:", final_inventory)
    print("Reorder Needed:", reorder_needed)
    print("Transactions Data:", transactions_data) # Print the dictionary


if __name__ == "__main__":
    main()
# Out:
# Final Inventory: 150
# Reorder Needed: True
# Transactions Data: {'morning': [120], 'afternoon': [85], 'evening': [95]}

# %% [markdown]
# ## Exercise 3: Employee Shift Calculator
# Calculate total hours worked by an employee across a week:
#
# - Monday: 8 hours
# - Tuesday: 6 hours
# - Wednesday: 0 hours (day off)
# - Thursday: 9 hours
# - Friday: 7 hours
# - Saturday: 5 hours
# - Sunday: 0 hours
#
# Calculate regular hours (first 40) and overtime hours (over 40) separately.

# %%
print("Enter work hours from monday to Sunday.")
work_hrs = []
hours = input()
work_hrs = [int(x) for x in hours.split()]
print(work_hrs, type(work_hrs))
overtime = 0
if sum(work_hrs) > 40:
    overtime = sum(work_hrs) - 40
    print(overtime)
    print("regular Hours 40")
else:
    print(sum(work_hrs))
# Out:
# Enter work hours from monday to Sunday.
# [8, 6, 0, 9, 7, 5, 0] <class 'list'>
# 35

# %%
try:
    work_hrs = []
    for i in range(7):  # Iterate through the days of the week
        hours = input(f"Enter hours for {i+1}: ")
        work_hrs.append(int(hours))
except ValueError:
    print("Invalid input. Please enter numbers only.")
    exit()

regular_hours = 0
for hour in work_hrs:
    if hour <= 40:
        regular_hours += hour

overtime = 0
if sum(work_hrs) > 40:
    overtime = sum(work_hrs) - 40

print("Regular Hours:", regular_hours)
if overtime > 0:
    print("Overtime Hours:", overtime)
# Out:
# Regular Hours: 40

# %% [markdown]
# # Float

# %% [markdown]
# ## Exercise 4: Coffee Shop Revenue
# A coffee shop tracks daily sales. Calculate average daily revenue from this week's data:
#
# - Monday: $342.50
# - Tuesday: $289.75
# - Wednesday: $456.25
# - Thursday: $378.90
# - Friday: $523.40
# - Saturday: $601.80
# - Sunday: $445.15
#
# Also calculate the percentage increase from Monday to Sunday.

# %%
# Exercise 4: Coffee Shop Revenue
print("\nExercise 4: Coffee Shop Revenue")
daily_sales = [342.50, 289.75, 456.25, 378.90, 523.40, 601.80, 445.15]
average_revenue = sum(daily_sales) / len(daily_sales)
monday_sales = daily_sales[0]
sunday_sales = daily_sales[6]
percentage_increase = ((sunday_sales - monday_sales) / monday_sales) * 100

print(f"Average daily revenue: ${average_revenue:.2f}")
print(f"Monday to Sunday increase: {percentage_increase:.1f}%")
# Out:
# Exercise 4: Coffee Shop Revenue
# Average daily revenue: $433.96
# Monday to Sunday increase: 30.0%

# %% [markdown]
# ## Exercise 5: Stock Portfolio Tracker
# Track a stock's performance. Starting price: $45.67
#
# - Day 1: +2.3% change
# - Day 2: -1.8% change
# - Day 3: +0.9% change
# - Day 4: +3.2% change
# - Day 5: -2.1% change
#
# Calculate the final price and total percentage change over the 5 days.

# %%
# Exercise 5: Stock Portfolio Tracker
print("\nExercise 5: Stock Portfolio Tracker")
starting_price = 45.67
changes = [2.3, -1.8, 0.9, 3.2, -2.1]
current_price = starting_price

for change in changes:
    current_price = current_price * (1 + change / 100)
    print(current_price)

total_percentage_change = ((current_price - starting_price) / starting_price) * 100

print(f"Starting price: ${starting_price:.2f}")
print(f"Final price: ${current_price:.2f}")
print(f"Total percentage change: {total_percentage_change:.2f}%")
# Out:
# Exercise 5: Stock Portfolio Tracker
# 46.72041
# 45.87944262
# 46.292357603579994
# 47.77371304689456
# 46.77046507290977
# Starting price: $45.67
# Final price: $46.77
# Total percentage change: 2.41%

# %% [markdown]
# ## Exercise 6: Recipe Scaling
# A recipe serves 4 people and requires:
#
# - 2.5 cups flour
# - 1.75 cups milk
# - 0.5 cups sugar
#
# Scale this recipe to serve 15 people. Calculate the new ingredient amounts.

# %%
serve_four = [2.5, 1.75, 0.5]
serve_one = [x/4 for x in serve_four]
serve_x =[x*15 for x in serve_one]
print(serve_x)
# Out:
# [9.375, 6.5625, 1.875]

# %%
# Exercise 6: Recipe Scaling
print("\nExercise 6: Recipe Scaling")
original_servings = 4
new_servings = int(input("Enter Number of servings: "))
scale_factor = new_servings / original_servings

flour = 2.5 * scale_factor
milk = 1.75 * scale_factor
sugar = 0.5 * scale_factor

print(f"For {new_servings} people:")
print(f"Flour: {flour:.2f} cups")
print(f"Milk: {milk:.2f} cups")
print(f"Sugar: {sugar:.2f} cups")
# Out:
# Exercise 6: Recipe Scaling
# For 15 people:
# Flour: 9.38 cups
# Milk: 6.56 cups
# Sugar: 1.88 cups

# %% [markdown]
# # Strings

# %% [markdown]
# ## Exercise 7: Name Formatting System
# A user types in their name in lowercase: ryan coogler.
#
# How would you standardize it for display?

# %%
name = input("Enter Your Name please: ")

formated_name = name.title()
print(formated_name)
# Out:
# Alvin Onsongo

# %% [markdown]
# ## Exercise 8: Phone Number Sanitization
# You receive phone numbers like: "+254-701-123-456"
#
# How do you extract only the digits?

# %%
phone = "+254-701-123-456"
digits_only = ''.join(char for char in phone if char.isdigit())
print(digits_only)  # Output: 254701123456
# Out:
# 254701123456

# %% [markdown]
# ## Exercise 9: Username Validator
# A valid username must be 5–12 characters and not contain spaces.
#
# How do you check and enforce this?

# %%
def user_name(username):
    if 5 <= len(username) <= 12 and ' ' not in username:
        print("Username is valid!")
    else:
        print("Invalid Username!")
        
user_name("ryan_coogler")
# Out:
# Username is valid!

# %%
username = "ryan_coogler"
is_valid = 5 <= len(username) <= 12 and ' ' not in username
print(is_valid)  # Output: True
# Out:
# True

# %% [markdown]
# # Boolean

# %% [markdown]
# ## Exercise 10: Email Verification Flag
# After signing up, a user has is_verified = False.
#
# What triggers this to become True, and how would the system behave differently?

# %%
is_verified = False
# After clicking verification link:
is_verified = True
print(is_verified)  # Output: True
# Out:
# True

# %% [markdown]
# ## Exercise 11: Permission Checker
# If is_admin = True, the user can delete posts.
#
# How does Boolean logic prevent accidental deletions?

# %%
is_admin = False
if is_admin:
    print("You can delete posts.")  # Output: User can delete posts.
else:
    print("You cannot delete posts!")
# Out:
# You cannot delete posts!

# %% [markdown]
# ## Exercise 13: Subscription Status
# Your app checks if a user’s is_premium flag is True.
#
# How might this be used to conditionally serve ads?

# %%
is_premium = False
if not is_premium:
    print("Showing ads...")  # Output: Showing ads...
# Out:
# Showing ads...

# %% [markdown]
# # Lists

# %% [markdown]
# ## Exercise 11: Grocery Cart System
# A user adds: "milk", "bread", "eggs" to their cart.
#
# Why is list the right structure?
# How would you remove "bread"?

# %%
cart = ["milk", "bread", "eggs"]
print(cart)
cart.remove("bread")
print(cart)
# Out:
# ['milk', 'bread', 'eggs']
# ['milk', 'eggs']

# %% [markdown]
# ## Exercise 12: Sensor Data Buffer
# Your IoT device records temperatures every minute.
#
# How do you keep only the last 10 readings?

# %%
readings = [23.1, 22.9, 23.3, 24.0, 23.7, 23.4, 22.8, 23.0, 23.2, 22.6, 23.1]
last_10 = readings[-10:]
print(last_10)
# Out:
# [22.9, 23.3, 24.0, 23.7, 23.4, 22.8, 23.0, 23.2, 22.6, 23.1]

# %% [markdown]
# ## Exercise 13: Student Grades Entry
# A teacher inputs scores: [89, 94, 78, 91]
#
# How would you compute average, highest, lowest?

# %%
scores = [89, 94, 78, 91]
average = sum(scores) / len(scores)
lowest = sorted(scores)
print(f"Average: {average:.2f}")
print(f"Highest: {lowest[3]:.2f}")
print(f"Lowest: {lowest[0]:.2f}")
# Out:
# Average: 88.00
# Highest: 94.00
# Lowest: 78.00

# %%
grades = [89, 94, 78, 91]
average = sum(grades) / len(grades)
highest = max(grades)
lowest = min(grades)
print(average, highest, lowest)  # Output: 88.0 94 78
# Out:
# 88.0 94 78

# %% [markdown]
# # Tuples

# %% [markdown]
# ## Exercise 14: GPS Coordinates Storage
# You store a location as (latitude, longitude).
#
# Why not use a list? What’s the implication of immutability?

# %%
location = (1.2921, 36.8219)
print(location[0], location[1])  # Latitude, Longitude
# Out:
# 1.2921 36.8219

# %% [markdown]
# ## Exercise 15: RGB Color Picker
# A designer stores a color as (255, 0, 128).
#
# When would a tuple be better than a list?

# %%
color = (255, 0, 128)
print(f"Red: {color[0]}, Green: {color[1]}, Blue: {color[2]}")
# Out:
# Red: 255, Green: 0, Blue: 128

# %% [markdown]
# ## Exercise 16: Immutable Menu Items
# Menu items with fixed price and name: ("Burger", 5.99)
#
# Why enforce immutability here?

# %%
menu_item = ("Burger", 5.99)
# menu_item[1] = 6.99  # This would raise a TypeError
print(menu_item)
# Out:
# ('Burger', 5.99)

# %% [markdown]
# # Dictionaries

# %% [markdown]
# ## Exercise 17: Student Report System
# Store names and grades: {"Allan": 89, "Amina": 94}
#
# How would you retrieve Amina’s grade?

# %%
report_system = {"Allan":89, "Amina":80, "Vicky": 89}
print(report_system["Amina"])
# Out:
# 80

# %% [markdown]
# ## Exercise 18: Product Catalog
# Product with fields: {"id": 203, "name": "Keyboard", "price": 2499}
#
# Why is dictionary better than list or tuple?

# %%
product = {"id": 203, "name": "Keyboard", "price": 2499}
print(product["name"])  # Output: Keyboard
# Out:
# Keyboard

# %% [markdown]
# ## Exercise 19: Login Credential Storage (Insecure Example)
# {"alvin": "12345", "amina": "qwerty"}
#
# How would you update a password?

# %%
user_password = {"allan": "12345", "amina": "qwerty"}
user_password["allan"] = "Azpfekf11wk.ck,"
print(user_password)
# Out:
# {'allan': 'Azpfekf11wk.ck,', 'amina': 'qwerty'}

# %% [markdown]
# # Sets

# %% [markdown]
# ## Exercise 20: Duplicate Email Checker
# You collect 10,000 emails. Many are duplicates.
#
# How would you store them efficiently?

# %%
emails = ["a@example.com", "b@example.com", "a@example.com"]
unique_emails = set(emails)
print(unique_emails)  # Output: {'a@example.com', 'b@example.com'}
# Out:
# {'a@example.com', 'b@example.com'}

# %% [markdown]
# ## Exercise 21: Tag-Based Filtering
# A blog post has tags: {“python”, “tutorial”, “beginner”}
#
# How would you check if “AI” is among them?

# %%
tags = {"python", "tutorial", "beginner"}
print("AI" in tags)  # Output: False
# Out:
# False

# %% [markdown]
# ## Exercise 22: Common Friends Finder
# You compare your friends with another user’s friends.
#
# What set operation helps here?

# %%
your_friends = {"Ken", "Jane", "Ali"}
their_friends = {"Ali", "Maria", "Ken"}
common = your_friends & their_friends
print(common)  # Output: {'Ken', 'Ali'}
# Out:
# {'Ali', 'Ken'}

# %% [markdown]
# # 🧩 Final Challenge: Mixed Data Types

# %% [markdown]
# ## Banking App
# Each user has:
#
# username: str
#
# balance: float
#
# transactions: list of floats
#
# How would you add a new transaction and update balance?

# %%
user = {
    "username": "allan",
    "balance": 1500.0,
    "transactions": [-200.0, 500.0, -100.0]
}
new_transaction = -300.0
user["transactions"].append(new_transaction)
user["balance"] += new_transaction
print(user)
# Out:
# {'username': 'allan', 'balance': 1200.0, 'transactions': [-200.0, 500.0, -100.0, -300.0]}

# %% [markdown]
# ## Expense Tracker
# Store your expenses using category (string), amount (float), and date (tuple of ints).
#
# Example: ("Food", 450.75, (2025, 7, 9))
# How would you store multiple entries and calculate total per category?

# %%
expenses = [("Food", 450.75, (2025, 7, 9)),
            ("Transport", 100.00, (2025, 7, 9)),
            ("Food", 200.00, (2025, 7, 8))]

from collections import defaultdict
totals = defaultdict(float)
for category, amount, _ in expenses:
    totals[category] += amount

print(dict(totals))  # Output: {'Food': 650.75, 'Transport': 100.0}
# Out:
# {'Food': 650.75, 'Transport': 100.0}

# %% [markdown]
# **Code Description**
#
# The code calculates the total expenses for different categories from a list of expenses. Each expense is represented as a tuple containing the category name (string), the amount (float), and the date of the expense. The code then aggregates these amounts by category using a `defaultdict` to store the totals. Finally, it prints the resulting dictionary of category totals.
#
# **Detailed Explanation**
#
# 1. **Data Structure:**
#    - `expenses`: This list contains tuples. Each tuple represents an expense and has the structure `(category, amount, date)`.
#    - `category`:  A string indicating the type of expense (e.g., "Food", "Transport").
#    - `amount`: A float representing the cost of the expense.
#    - `date`: A tuple representing the date of the expense (year, month, day).
#
# 2. **`defaultdict`:**
#    - `from collections import defaultdict`: Imports the `defaultdict` class from the `collections` module.
#    - `totals = defaultdict(float)`:  Creates a `defaultdict`. A `defaultdict` is a subclass of `dict`. The key difference is that if you try to access a key that doesn't exist in a `defaultdict`, it automatically creates that key and assigns it a default value. In this case, the default value is `float`, meaning that any new category will initially have a total of 0.0. This avoids the need to check if a category already exists in the dictionary.
#
# 3. **Iteration and Aggregation:**
#    - `for category, amount, _ in expenses:`:  This loop iterates through each tuple in the `expenses` list. The `_` is used to ignore the date, as it's not needed for this calculation.  The `category` and `amount` variables are unpacked from the tuple for use in the calculation.
#    - `totals[category] += amount`: For each expense, the `amount` is added to the total for the corresponding `category` in the `totals` dictionary.  If the `category` doesn't exist in `totals`, the `defaultdict` creates it with a default value of `0.0`, and then the amount is added. If the category *does* exist, the amount is simply added to the existing total.
#
# 4. **Printing the Result:**
#    - `print(dict(totals))`: The `dict()` constructor is used to convert the `defaultdict` back into a regular Python dictionary before printing it. This is done because the output format is typically a standard dictionary.
#
# **Built-in Methods Used**
#
# * **`defaultdict(float)`:** This is a built-in class from the `collections` module. It creates a dictionary-like object that automatically initializes missing keys with a default value.
# * **`+=` (Augmented Assignment Operator):**  This operator is used to add the `amount` to the existing total for a category.  It's shorthand for `totals[category] = totals[category] + amount`.
# * **`dict()` Constructor:**  This is a built-in constructor that creates a dictionary from an iterable (in this case, the `defaultdict`).
# * **`for` loop**: The use of the `for` loop is a built in python syntax to iterate through a sequence or iterable.

# %% [markdown]
# ## Library System
# Track books using a dictionary with title (string), author (string), available (bool), and borrow_count (int).
#
# How do you check availability and update borrow count?

# %%
book = {"title": "1984", "author": "Orwell", "available": True, "borrow_count": 3}
if book["available"]:
    book["borrow_count"] += 1
    book["available"] = False
print(book)
# Out:
# {'title': '1984', 'author': 'Orwell', 'available': False, 'borrow_count': 4}

# %% [markdown]
# ## Music Playlist Organizer
# A playlist is a list of tuples: (song_name, artist, duration_in_seconds)
#
# How would you compute total duration and search songs by artist?

# %%
playlist = [("By Your Side", "Sade", 265),
            ("DNA", "Kendrik Lamar", 185),
            ("Rainy Days and Mondays", "The Carpenters", 211)]

total_duration = sum(song[2] for song in playlist)
songs_by_sade = [song for song in playlist if song[1] == "Sade"]
print(total_duration)
print(songs_by_sade)
# Out:
# 661
# [('By Your Side', 'Sade', 265)]

# %% [markdown]
# ## Flight Seat Booking System
# Track booked seats as a dictionary where keys are seat numbers (str), and values are passenger details:
#
# name: str
#
# checked_in: bool
#
# How would you check if a seat is taken, or count checked-in passengers?

# %%
seats = {
    "1A": {"name": "Allan", "checked_in": True},
    "1B": {"name": "Amina", "checked_in": False},
    "1C": {"name": "John", "checked_in": True}
}

is_taken = "1A" in seats
checked_in_count = sum(1 for s in seats.values() if s["checked_in"])
print(is_taken)          # Output: True
print(checked_in_count)  # Output: 2
# Out:
# True
# 2
